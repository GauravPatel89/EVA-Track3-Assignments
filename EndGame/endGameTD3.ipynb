# %% [markdown]
# <a href="https://colab.research.google.com/github/GauravPatel89/EVA-Track3-Assignments/blob/master/EndGame/endGameTD3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Twin-Delayed DDPG

# %%
# Mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# Work in endGameTD3 in google drive so that even after session ends work will be available
# %cd '/content/drive/My Drive/endGameTD3'
# !pwd
# Out:
# /content/drive/My Drive/endGameTD3
# /content/drive/My Drive/endGameTD3

# %% [markdown]
# To run rest of the code following files should be available in working directory
# 1. car.png
# 2. citymap.png
# 3. MASK1.png
# 4. endGameEnv.py
# 5. endGameModels.py
# 6. endGameUtilities.py
#
# These files can be found [here.](https://github.com/GauravPatel89/EVA-Track3-Assignments/tree/master/EndGame)

# %% [markdown]
# ## Importing the libraries

# %%
import os
import time
import random
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
from collections import deque

from endGameEnv import car,carEndgameEnv
from endGameModels import ReplayBuffer,Actor,Critic,TD3

# %%
def evaluate_policy(policy, eval_episodes=3):
    avg_reward = 0.
    print('')
    print("----------- Evaluation -------------")
    for _ in range(eval_episodes):
        obs = env.reset()
        print(env.car)
        done = False
        while not done:
            action = policy.select_action(np.array(obs))
            obs, reward, done = env.step(action)
            avg_reward += reward
        #print('episode done')
    avg_reward /= eval_episodes
    print ("---------------------------------------")
    print ("Average Reward over the Evaluation Step: %f" % (avg_reward))
    print ("---------------------------------------")
    print('')
    return avg_reward

# %% [markdown]
# ## We set the parameters

# %%
env_name = "carEndGameEnv" 
seed = 0 
save_models = True

# %% [markdown]
# ## We create a file name for the two saved models: the Actor and Critic models

# %%
file_name = "%s_%s_%s" % ("TD3", env_name, str(seed))
print ("---------------------------------------")
print ("Settings: %s" % (file_name))
print ("---------------------------------------")
# Out:
# ---------------------------------------
# Settings: TD3_carEndGameEnv_0
# ---------------------------------------

# %% [markdown]
# ## We create a folder inside which will be saved the trained models

# %%
if not os.path.exists("./results"):
  os.makedirs("./results")
if save_models and not os.path.exists("./pytorch_models"):
  os.makedirs("./pytorch_models")

# %% [markdown]
# ## We create the carEndGame environment

# %%
car1 = car(carImgPath='./car.png',size= (20,10),velocity=(2.0,0.0),angle=0.0)
env = carEndgameEnv(mapImgPath='./citymap.png',maskImgPath='./MASK1.png',carObj=car1)

# %% [markdown]
# ## We set seeds and we get the necessary information on the states and actions in the chosen environment

# %%
torch.manual_seed(seed)
np.random.seed(seed)
state_dim = env.state_dim
action_dim = env.action_dim
max_action = env.max_action

# %% [markdown]
# ## We create the policy network

# %%
policy = TD3(state_dim, action_dim, max_action)

# %% [markdown]
# ## We create the Experience Replay memory

# %%
replay_buffer = ReplayBuffer()

# %% [markdown]
# ## We define a list where all the evaluation results over 3 episodes are stored

# %%
evaluations = [evaluate_policy(policy)]
# Out:
# ----------- Evaluation -------------
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Episode Done:Car stuck
# Episode steps: 1290  Sand count:  1130  Road Count:  160
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Episode Done:Car stuck
# Episode steps: 1290  Sand count:  1130  Road Count:  160
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Episode Done:Car stuck
# Episode steps: 1095  Sand count:  915  Road Count:  180
# ---------------------------------------
# Average Reward over the Evaluation Step: -5791.133333
# ---------------------------------------

# %% [markdown]
# ## We initialize the variables

# %%
start_timesteps = 5e3  # Number of iterations/timesteps before which the model randomly chooses an action, and after which it starts to use the policy network
eval_freq = 2e3  # How often the evaluation step is performed (after how many timesteps)
max_timesteps = 2e5 # Total number of iterations/timesteps
expl_noise = 0.1  # Exploration noise - STD value of exploration Gaussian noise
batch_size = 100  # Size of the batch
discount = 0.99  # Discount factor gamma, used in the calculation of the total discounted reward
tau = 0.005  # Target network update rate
policy_noise = 0.2  # STD of Gaussian noise added to the actions for the exploration purposes
noise_clip = 0.5  # Maximum value of the Gaussian noise added to the actions (policy)
policy_freq = 2  # Number of iterations to wait before the policy network (Actor model) is updated

# %%
# Initialize training specific variables
total_timesteps = 0
timesteps_since_eval = 0
episode_num = 0
done = True
t0 = time.time()
episode_reward = 0
episode_timesteps = 0

# %% [markdown]
# ## Training

# %%
max_timesteps = 200000
while total_timesteps < max_timesteps:
  
  # If the episode is done
  if done:

    # If we are not at the very beginning, we start the training process of the model
    if total_timesteps != 0:
      print("Total Timesteps: {} Episode Num: {} Reward: {}".format(total_timesteps, episode_num, episode_reward))
      policy.train(replay_buffer, episode_timesteps, batch_size, discount, tau, policy_noise, noise_clip, policy_freq)

    # We evaluate the episode and we save the policy
    if timesteps_since_eval >= eval_freq:
      timesteps_since_eval %= eval_freq
      evaluations.append(evaluate_policy(policy))
      fName = '%s_%d'%(file_name,total_timesteps)
      policy.save(fName, directory="./pytorch_models")  # save current model with current timestep as name subscript
      np.save("./results/%s_%d" % (file_name,total_timesteps), evaluations)
    
    # When the training step is done, we reset the state of the environment
    obs = env.reset()
    print(env.car)
    
    # Set the Done to False
    done = False
    
    # Set rewards and episode timesteps to zero
    episode_reward = 0
    episode_timesteps = 0
    episode_num += 1
  
  # Before 10000 timesteps, we play random actions
  if total_timesteps < start_timesteps:
    action = env.sampleActionSpace()
  else: # After 10000 timesteps, we switch to the model
    action = policy.select_action(np.array(obs))
    # If the explore_noise parameter is not 0, we add noise to the action and we clip it
    if expl_noise != 0:
      action = (action + np.random.normal(0, expl_noise, size=env.action_dim)).clip(-1*env.max_action, env.max_action)
  
  # The agent performs the action in the environment, then reaches the next state and receives the reward
  new_obs, reward, done = env.step(action)
  
  # We check if the episode is done
  done_bool = 0 if episode_timesteps + 1 == env._max_episode_steps else float(done)
  
  # We increase the total reward
  episode_reward += reward
  
  # We store the new transition into the Experience Replay memory (ReplayBuffer)
  replay_buffer.add((obs, new_obs, action, reward, done_bool))

  # We update the state, the episode timestep, the total timesteps, and the timesteps since the evaluation of the policy
  obs = new_obs
  episode_timesteps += 1
  total_timesteps += 1
  timesteps_since_eval += 1 

# We add the last policy evaluation to our list of evaluations and we save our model
evaluations.append(evaluate_policy(policy))
if save_models: policy.save("%s" % (file_name), directory="./pytorch_models")
np.save("./results/%s_%d" % (file_name,total_timesteps), evaluations)
# Out:
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 260 476 )
# Episode Done:Car stuck
# Episode steps: 656  Sand count:  592  Road Count:  64
# Total Timesteps: 656 Episode Num: 1 Reward: -4550.6
# Avg CriticLoss:  34.565437158433404  Avg ActorLoss  3.6037814637430285  ActorLR:  [0.0001]  CriticLR:  [0.0001]
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Episode Done:Car stuck
# Episode steps: 2200  Sand count:  1996  Road Count:  204
# Total Timesteps: 2856 Episode Num: 2 Reward: -19943.80000000007
# Avg CriticLoss:  44.213279956470835  Avg ActorLoss  16.23432702107863  ActorLR:  [0.0001]  CriticLR:  [0.0001]
#
# ----------- Evaluation -------------
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 260 476 )
# Goal:( 472 335 )
# Goal:( 501 608 )
# Episode Done:All goals achieved
# Episode steps: 4643  Sand count:  1024  Road Count:  3619
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 260 476 )
# Goal:( 1130 236 )
# Goal:( 150 200 )
# Episode Done:All goals achieved
# Episode steps: 2505  Sand count:  635  Road Count:  1870
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 611 29 )
# Goal:( 501 608 )
# Goal:( 885 568 )
# Episode Done:All goals achieved
# Episode steps: 2595  Sand count:  446  Road Count:  2149
# ---------------------------------------
# Average Reward over the Evaluation Step: -4930.600000
# ---------------------------------------
#
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Episode Done:Car stuck
# Episode steps: 1229  Sand count:  1041  Road Count:  188
# Total Timesteps: 4085 Episode Num: 3 Reward: -7584.400000000003
# Avg CriticLoss:  61.072875202138604  Avg ActorLoss  30.974782340016375  ActorLR:  [0.0001]  CriticLR:  [0.0001]
#
# ----------- Evaluation -------------
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 1130 236 )
# Goal:( 150 200 )
# Goal:( 700 583 )
# Episode Done:All goals achieved
# Episode steps: 2514  Sand count:  568  Road Count:  1946
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 611 29 )
# Goal:( 501 608 )
# Goal:( 150 200 )
# Episode Done:All goals achieved
# Episode steps: 1845  Sand count:  797  Road Count:  1048
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 700 583 )
# Goal:( 346 426 )
# Goal:( 885 568 )
# Episode Done:All goals achieved
# Episode steps: 1542  Sand count:  548  Road Count:  994
# ---------------------------------------
# Average Reward over the Evaluation Step: -2606.266667
# ---------------------------------------
#
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 501 608 )
# Goal:( 885 568 )
# Goal:( 611 29 )
# Episode Done:All goals achieved
# Episode steps: 1992  Sand count:  1251  Road Count:  741
# Total Timesteps: 6077 Episode Num: 4 Reward: -7027.100000000002
# Avg CriticLoss:  79.73225019638797  Avg ActorLoss  39.15054584794255  ActorLR:  [0.0001]  CriticLR:  [0.0001]
#
# ----------- Evaluation -------------
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 260 476 )
# Goal:( 501 608 )
# Goal:( 1130 236 )
# Episode Done:All goals achieved
# Episode steps: 1608  Sand count:  286  Road Count:  1322
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 501 608 )
# Goal:( 346 426 )
# Goal:( 1130 236 )
# Episode Done:All goals achieved
# Episode steps: 2918  Sand count:  445  Road Count:  2473
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 700 583 )
# Episode Done:Max episode steps exhausted
# Episode steps: 5000  Sand count:  762  Road Count:  4238
# ---------------------------------------
# Average Reward over the Evaluation Step: -2878.566667
# ---------------------------------------
#
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 260 476 )
# Goal:( 501 608 )
# Goal:( 700 583 )
# Episode Done:All goals achieved
# Episode steps: 1206  Sand count:  97  Road Count:  1109
# Total Timesteps: 7283 Episode Num: 5 Reward: -435.8999999999962
# Avg CriticLoss:  91.21273954274444  Avg ActorLoss  46.10381572717063  ActorLR:  [0.0001]  CriticLR:  [0.0001]
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 150 200 )
# Goal:( 1130 236 )
# Goal:( 260 476 )
# Episode Done:All goals achieved
# Episode steps: 3669  Sand count:  418  Road Count:  3251
# Total Timesteps: 10952 Episode Num: 6 Reward: -2208.7000000000503
# Avg CriticLoss:  121.8654819123587  Avg ActorLoss  52.091467016495095  ActorLR:  [0.0001]  CriticLR:  [9e-05]
#
# ----------- Evaluation -------------
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 1415 626 )
# Goal:( 700 583 )
# Goal:( 150 200 )
# Episode Done:All goals achieved
# Episode steps: 4731  Sand count:  447  Road Count:  4284
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 700 583 )
# Goal:( 1415 626 )
# Goal:( 885 568 )
# Episode Done:All goals achieved
# Episode steps: 4218  Sand count:  317  Road Count:  3901
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 1415 626 )
# Goal:( 700 583 )
# Goal:( 150 200 )
# Episode Done:All goals achieved
# Episode steps: 4731  Sand count:  447  Road Count:  4284
# ---------------------------------------
# Average Reward over the Evaluation Step: -1662.766667
# ---------------------------------------
#
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 150 200 )
# Goal:( 260 476 )
# Goal:( 700 583 )
# Episode Done:All goals achieved
# Episode steps: 1967  Sand count:  353  Road Count:  1614
# Total Timesteps: 12919 Episode Num: 7 Reward: -1617.6000000000322
# Avg CriticLoss:  162.73896770157302  Avg ActorLoss  59.10073359168964  ActorLR:  [0.0001]  CriticLR:  [9e-05]
#
# ----------- Evaluation -------------
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 150 200 )
# Goal:( 1130 236 )
# Goal:( 501 608 )
# Episode Done:All goals achieved
# Episode steps: 3577  Sand count:  711  Road Count:  2866
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 885 568 )
# Goal:( 1415 626 )
# Goal:( 472 335 )
# Episode Done:All goals achieved
# Episode steps: 2663  Sand count:  221  Road Count:  2442
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 611 29 )
# Goal:( 346 426 )
# Goal:( 501 608 )
# Episode Done:All goals achieved
# Episode steps: 2195  Sand count:  352  Road Count:  1843
# ---------------------------------------
# Average Reward over the Evaluation Step: -2551.166667
# ---------------------------------------
#
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 346 426 )
# Goal:( 885 568 )
# Goal:( 260 476 )
# Episode Done:All goals achieved
# Episode steps: 1796  Sand count:  354  Road Count:  1442
# Total Timesteps: 14715 Episode Num: 8 Reward: -1313.4000000000015
# Avg CriticLoss:  190.1865039944383  Avg ActorLoss  63.04069547504518  ActorLR:  [0.0001]  CriticLR:  [9e-05]
#
# ----------- Evaluation -------------
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 885 568 )
# Goal:( 700 583 )
# Goal:( 1130 236 )
# Episode Done:All goals achieved
# Episode steps: 1775  Sand count:  460  Road Count:  1315
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 501 608 )
# Goal:( 472 335 )
# Goal:( 611 29 )
# Episode Done:All goals achieved
# Episode steps: 1463  Sand count:  490  Road Count:  973
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 346 426 )
# Goal:( 885 568 )
# Goal:( 1130 236 )
# Episode Done:All goals achieved
# Episode steps: 1510  Sand count:  370  Road Count:  1140
# ---------------------------------------
# Average Reward over the Evaluation Step: -1700.200000
# ---------------------------------------
#
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 611 29 )
# Goal:( 260 476 )
# Goal:( 150 200 )
# Episode Done:All goals achieved
# Episode steps: 2155  Sand count:  608  Road Count:  1547
# Total Timesteps: 16870 Episode Num: 9 Reward: -2998.5000000000164
# Avg CriticLoss:  208.6064142744945  Avg ActorLoss  67.46026558577323  ActorLR:  [0.0001]  CriticLR:  [9e-05]
#
# ----------- Evaluation -------------
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 611 29 )
# Goal:( 260 476 )
# Goal:( 700 583 )
# Episode Done:All goals achieved
# Episode steps: 3350  Sand count:  1189  Road Count:  2161
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 472 335 )
# Goal:( 1415 626 )
# Goal:( 611 29 )
# Episode Done:All goals achieved
# Episode steps: 2118  Sand count:  736  Road Count:  1382
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 472 335 )
# Goal:( 1130 236 )
# Goal:( 150 200 )
# Episode Done:All goals achieved
# Episode steps: 1879  Sand count:  920  Road Count:  959
# ---------------------------------------
# Average Reward over the Evaluation Step: -5615.000000
# ---------------------------------------
#
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 1415 626 )
# Goal:( 885 568 )
# Goal:( 700 583 )
# Episode Done:All goals achieved
# Episode steps: 3518  Sand count:  975  Road Count:  2543
# Total Timesteps: 20388 Episode Num: 10 Reward: -5322.899999999912
# Avg CriticLoss:  241.5516618790445  Avg ActorLoss  72.57906806082669  ActorLR:  [9e-05]  CriticLR:  [8.1e-05]
#
# ----------- Evaluation -------------
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 885 568 )
# Goal:( 346 426 )
# Goal:( 150 200 )
# Episode Done:All goals achieved
# Episode steps: 1989  Sand count:  1323  Road Count:  666
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 501 608 )
# Goal:( 346 426 )
# Goal:( 885 568 )
# Episode Done:All goals achieved
# Episode steps: 2596  Sand count:  1533  Road Count:  1063
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 700 583 )
# Goal:( 150 200 )
# Goal:( 885 568 )
# Episode Done:All goals achieved
# Episode steps: 3394  Sand count:  1580  Road Count:  1814
# ---------------------------------------
# Average Reward over the Evaluation Step: -7314.566667
# ---------------------------------------
#
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 501 608 )
# Goal:( 472 335 )
# Goal:( 611 29 )
# Episode Done:All goals achieved
# Episode steps: 2393  Sand count:  1352  Road Count:  1041
# Total Timesteps: 22781 Episode Num: 11 Reward: -6782.499999999972
# Avg CriticLoss:  258.4758246709152  Avg ActorLoss  79.28021259682477  ActorLR:  [9e-05]  CriticLR:  [8.1e-05]
#
# ----------- Evaluation -------------
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 1415 626 )
# Goal:( 501 608 )
# Goal:( 611 29 )
# Episode Done:All goals achieved
# Episode steps: 3307  Sand count:  995  Road Count:  2312
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 1415 626 )
# Goal:( 1130 236 )
# Goal:( 501 608 )
# Episode Done:All goals achieved
# Episode steps: 3952  Sand count:  1232  Road Count:  2720
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 346 426 )
# Goal:( 1130 236 )
# Goal:( 611 29 )
# Episode Done:All goals achieved
# Episode steps: 2479  Sand count:  1703  Road Count:  776
# ---------------------------------------
# Average Reward over the Evaluation Step: -6389.000000
# ---------------------------------------
#
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 1130 236 )
# Goal:( 260 476 )
# Goal:( 501 608 )
# Episode Done:All goals achieved
# Episode steps: 2493  Sand count:  861  Road Count:  1632
# Total Timesteps: 25274 Episode Num: 12 Reward: -4341.200000000021
# Avg CriticLoss:  293.38854052271654  Avg ActorLoss  85.04741713687974  ActorLR:  [9e-05]  CriticLR:  [8.1e-05]
#
# ----------- Evaluation -------------
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 611 29 )
# Goal:( 501 608 )
# Goal:( 472 335 )
# Episode Done:All goals achieved
# Episode steps: 3005  Sand count:  999  Road Count:  2006
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Episode Done:Max episode steps exhausted
# Episode steps: 5000  Sand count:  524  Road Count:  4476
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 501 608 )
# Goal:( 611 29 )
# Goal:( 700 583 )
# Episode Done:All goals achieved
# Episode steps: 2736  Sand count:  638  Road Count:  2098
# ---------------------------------------
# Average Reward over the Evaluation Step: -5941.733333
# ---------------------------------------
#
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 700 583 )
# Goal:( 1130 236 )
# Goal:( 346 426 )
# Episode Done:All goals achieved
# Episode steps: 2821  Sand count:  501  Road Count:  2320
# Total Timesteps: 28095 Episode Num: 13 Reward: -2037.8000000000038
# Avg CriticLoss:  300.1739314531274  Avg ActorLoss  89.62704258445136  ActorLR:  [9e-05]  CriticLR:  [8.1e-05]
#
# ----------- Evaluation -------------
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 611 29 )
# Goal:( 150 200 )
# Goal:( 1415 626 )
# Episode Done:All goals achieved
# Episode steps: 3596  Sand count:  530  Road Count:  3066
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 611 29 )
# Goal:( 150 200 )
# Goal:( 1130 236 )
# Episode Done:All goals achieved
# Episode steps: 2513  Sand count:  494  Road Count:  2019
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 1415 626 )
# Goal:( 885 568 )
# Goal:( 150 200 )
# Episode Done:All goals achieved
# Episode steps: 2702  Sand count:  583  Road Count:  2119
# ---------------------------------------
# Average Reward over the Evaluation Step: -2515.266667
# ---------------------------------------
#
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 700 583 )
# Goal:( 150 200 )
# Goal:( 611 29 )
# Episode Done:All goals achieved
# Episode steps: 2409  Sand count:  495  Road Count:  1914
# Total Timesteps: 30504 Episode Num: 14 Reward: -2189.000000000002
# Avg CriticLoss:  329.42116410131524  Avg ActorLoss  93.28130598689769  ActorLR:  [9e-05]  CriticLR:  [7.290000000000001e-05]
#
# ----------- Evaluation -------------
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 700 583 )
# Goal:( 1415 626 )
# Goal:( 346 426 )
# Episode Done:All goals achieved
# Episode steps: 4431  Sand count:  382  Road Count:  4049
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 700 583 )
# Goal:( 611 29 )
# Goal:( 260 476 )
# Episode Done:All goals achieved
# Episode steps: 3124  Sand count:  377  Road Count:  2747
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 885 568 )
# Goal:( 611 29 )
# Goal:( 150 200 )
# Episode Done:All goals achieved
# Episode steps: 3025  Sand count:  434  Road Count:  2591
# ---------------------------------------
# Average Reward over the Evaluation Step: -1790.966667
# ---------------------------------------
#
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 700 583 )
# Goal:( 150 200 )
# Episode Done:Max episode steps exhausted
# Episode steps: 5000  Sand count:  339  Road Count:  4661
# Total Timesteps: 35504 Episode Num: 15 Reward: -2001.5000000000568
# Avg CriticLoss:  345.82942584838867  Avg ActorLoss  97.1188458404541  ActorLR:  [9e-05]  CriticLR:  [7.290000000000001e-05]
#
# ----------- Evaluation -------------
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 472 335 )
# Goal:( 346 426 )
# Goal:( 885 568 )
# Episode Done:All goals achieved
# Episode steps: 2348  Sand count:  156  Road Count:  2192
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 472 335 )
# Goal:( 346 426 )
# Goal:( 150 200 )
# Episode Done:All goals achieved
# Episode steps: 1908  Sand count:  225  Road Count:  1683
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 150 200 )
# Goal:( 346 426 )
# Goal:( 472 335 )
# Episode Done:All goals achieved
# Episode steps: 1201  Sand count:  236  Road Count:  965
# ---------------------------------------
# Average Reward over the Evaluation Step: -1000.800000
# ---------------------------------------
#
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 346 426 )
# Goal:( 501 608 )
# Goal:( 150 200 )
# Episode Done:All goals achieved
# Episode steps: 1190  Sand count:  57  Road Count:  1133
# Total Timesteps: 36694 Episode Num: 16 Reward: -55.300000000000296
# Avg CriticLoss:  352.3055291440307  Avg ActorLoss  99.10811513692391  ActorLR:  [9e-05]  CriticLR:  [7.290000000000001e-05]
#
# ----------- Evaluation -------------
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Episode Done:Max episode steps exhausted
# Episode steps: 5000  Sand count:  226  Road Count:  4774
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 700 583 )
# Goal:( 346 426 )
# Goal:( 472 335 )
# Episode Done:All goals achieved
# Episode steps: 3715  Sand count:  289  Road Count:  3426
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 1130 236 )
# Goal:( 150 200 )
# Goal:( 885 568 )
# Episode Done:All goals achieved
# Episode steps: 3379  Sand count:  328  Road Count:  3051
# ---------------------------------------
# Average Reward over the Evaluation Step: -1956.700000
# ---------------------------------------
#
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 1130 236 )
# Goal:( 260 476 )
# Goal:( 1415 626 )
# Episode Done:All goals achieved
# Episode steps: 3815  Sand count:  236  Road Count:  3579
# Total Timesteps: 40509 Episode Num: 17 Reward: -2436.7000000000116
# Avg CriticLoss:  343.25944049080266  Avg ActorLoss  99.17895853385076  ActorLR:  [8.1e-05]  CriticLR:  [6.561000000000002e-05]
#
# ----------- Evaluation -------------
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 260 476 )
# Goal:( 611 29 )
# Goal:( 1130 236 )
# Episode Done:All goals achieved
# Episode steps: 1084  Sand count:  17  Road Count:  1067
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 885 568 )
# Goal:( 346 426 )
# Goal:( 501 608 )
# Episode Done:All goals achieved
# Episode steps: 2357  Sand count:  140  Road Count:  2217
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 611 29 )
# Goal:( 150 200 )
# Episode Done:Max episode steps exhausted
# Episode steps: 5000  Sand count:  164  Road Count:  4836
# ---------------------------------------
# Average Reward over the Evaluation Step: -686.666667
# ---------------------------------------
#
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 700 583 )
# Goal:( 501 608 )
# Goal:( 611 29 )
# Episode Done:All goals achieved
# Episode steps: 4139  Sand count:  247  Road Count:  3892
# Total Timesteps: 44648 Episode Num: 18 Reward: -3133.2000000000007
# Avg CriticLoss:  352.8411271251265  Avg ActorLoss  102.10382573712302  ActorLR:  [8.1e-05]  CriticLR:  [6.561000000000002e-05]
#
# ----------- Evaluation -------------
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 260 476 )
# Goal:( 346 426 )
# Goal:( 501 608 )
# Episode Done:All goals achieved
# Episode steps: 2545  Sand count:  197  Road Count:  2348
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 346 426 )
# Goal:( 1415 626 )
# Goal:( 700 583 )
# Episode Done:All goals achieved
# Episode steps: 2214  Sand count:  45  Road Count:  2169
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 1415 626 )
# Goal:( 700 583 )
# Goal:( 885 568 )
# Episode Done:All goals achieved
# Episode steps: 4687  Sand count:  315  Road Count:  4372
# ---------------------------------------
# Average Reward over the Evaluation Step: -1008.766667
# ---------------------------------------
#
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 885 568 )
# Goal:( 700 583 )
# Goal:( 1415 626 )
# Episode Done:All goals achieved
# Episode steps: 4084  Sand count:  178  Road Count:  3906
# Total Timesteps: 48732 Episode Num: 19 Reward: -837.9999999999858
# Avg CriticLoss:  348.15507702729377  Avg ActorLoss  105.62039872037792  ActorLR:  [8.1e-05]  CriticLR:  [6.561000000000002e-05]
#
# ----------- Evaluation -------------
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 260 476 )
# Goal:( 1130 236 )
# Goal:( 501 608 )
# Episode Done:All goals achieved
# Episode steps: 2608  Sand count:  176  Road Count:  2432
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 501 608 )
# Goal:( 472 335 )
# Goal:( 1130 236 )
# Episode Done:All goals achieved
# Episode steps: 3584  Sand count:  155  Road Count:  3429
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 346 426 )
# Goal:( 472 335 )
# Goal:( 1130 236 )
# Episode Done:All goals achieved
# Episode steps: 1831  Sand count:  44  Road Count:  1787
# ---------------------------------------
# Average Reward over the Evaluation Step: -902.400000
# ---------------------------------------
#
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 611 29 )
# Goal:( 346 426 )
# Goal:( 1130 236 )
# Episode Done:All goals achieved
# Episode steps: 2120  Sand count:  81  Road Count:  2039
# Total Timesteps: 50852 Episode Num: 20 Reward: -2.499999999998863
# Avg CriticLoss:  354.02822106559324  Avg ActorLoss  107.77532544405955  ActorLR:  [8.1e-05]  CriticLR:  [5.904900000000002e-05]
#
# ----------- Evaluation -------------
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 260 476 )
# Episode Done:Max episode steps exhausted
# Episode steps: 5000  Sand count:  335  Road Count:  4665
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Episode Done:Max episode steps exhausted
# Episode steps: 5000  Sand count:  335  Road Count:  4665
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 501 608 )
# Goal:( 885 568 )
# Goal:( 346 426 )
# Episode Done:All goals achieved
# Episode steps: 1790  Sand count:  80  Road Count:  1710
# ---------------------------------------
# Average Reward over the Evaluation Step: -1818.066667
# ---------------------------------------
#
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 260 476 )
# Goal:( 346 426 )
# Goal:( 150 200 )
# Episode Done:All goals achieved
# Episode steps: 550  Sand count:  210  Road Count:  340
# Total Timesteps: 51402 Episode Num: 21 Reward: -1078.4
# Avg CriticLoss:  358.8334326449308  Avg ActorLoss  109.31722589666194  ActorLR:  [8.1e-05]  CriticLR:  [5.904900000000002e-05]
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 885 568 )
# Goal:( 150 200 )
# Goal:( 472 335 )
# Episode Done:All goals achieved
# Episode steps: 3080  Sand count:  486  Road Count:  2594
# Total Timesteps: 54482 Episode Num: 22 Reward: -2676.2000000000407
# Avg CriticLoss:  351.49490371555476  Avg ActorLoss  110.55159697594581  ActorLR:  [8.1e-05]  CriticLR:  [5.904900000000002e-05]
#
# ----------- Evaluation -------------
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 885 568 )
# Goal:( 1130 236 )
# Goal:( 501 608 )
# Episode Done:All goals achieved
# Episode steps: 1824  Sand count:  260  Road Count:  1564
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Episode Done:Max episode steps exhausted
# Episode steps: 5000  Sand count:  326  Road Count:  4674
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 501 608 )
# Goal:( 611 29 )
# Goal:( 472 335 )
# Episode Done:All goals achieved
# Episode steps: 1784  Sand count:  103  Road Count:  1681
# ---------------------------------------
# Average Reward over the Evaluation Step: -1177.366667
# ---------------------------------------
#
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 260 476 )
# Goal:( 700 583 )
# Goal:( 346 426 )
# Episode Done:All goals achieved
# Episode steps: 3547  Sand count:  170  Road Count:  3377
# Total Timesteps: 58029 Episode Num: 23 Reward: -1230.5000000000073
# Avg CriticLoss:  363.0286233997157  Avg ActorLoss  113.18326173475302  ActorLR:  [8.1e-05]  CriticLR:  [5.904900000000002e-05]
#
# ----------- Evaluation -------------
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 611 29 )
# Goal:( 885 568 )
# Goal:( 1130 236 )
# Episode Done:All goals achieved
# Episode steps: 2370  Sand count:  112  Road Count:  2258
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 700 583 )
# Goal:( 885 568 )
# Goal:( 472 335 )
# Episode Done:All goals achieved
# Episode steps: 4117  Sand count:  293  Road Count:  3824
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 700 583 )
# Goal:( 346 426 )
# Goal:( 1415 626 )
# Episode Done:All goals achieved
# Episode steps: 4750  Sand count:  269  Road Count:  4481
# ---------------------------------------
# Average Reward over the Evaluation Step: -1120.033333
# ---------------------------------------
#
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 150 200 )
# Goal:( 885 568 )
# Goal:( 1415 626 )
# Episode Done:All goals achieved
# Episode steps: 2359  Sand count:  250  Road Count:  2109
# Total Timesteps: 60388 Episode Num: 24 Reward: -676.1000000000089
# Avg CriticLoss:  383.299772032139  Avg ActorLoss  114.03064951910817  ActorLR:  [7.290000000000001e-05]  CriticLR:  [5.314410000000002e-05]
#
# ----------- Evaluation -------------
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 1130 236 )
# Goal:( 501 608 )
# Goal:( 1415 626 )
# Episode Done:All goals achieved
# Episode steps: 3886  Sand count:  123  Road Count:  3763
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 501 608 )
# Goal:( 346 426 )
# Goal:( 1415 626 )
# Episode Done:All goals achieved
# Episode steps: 4238  Sand count:  101  Road Count:  4137
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 700 583 )
# Goal:( 1415 626 )
# Episode Done:Max episode steps exhausted
# Episode steps: 5000  Sand count:  217  Road Count:  4783
# ---------------------------------------
# Average Reward over the Evaluation Step: -411.366667
# ---------------------------------------
#
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 260 476 )
# Goal:( 472 335 )
# Goal:( 150 200 )
# Episode Done:All goals achieved
# Episode steps: 2713  Sand count:  272  Road Count:  2441
# Total Timesteps: 63101 Episode Num: 25 Reward: -1947.2999999999881
# Avg CriticLoss:  381.4296247156792  Avg ActorLoss  115.02537930886156  ActorLR:  [7.290000000000001e-05]  CriticLR:  [5.314410000000002e-05]
#
# ----------- Evaluation -------------
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 700 583 )
# Episode Done:Max episode steps exhausted
# Episode steps: 5000  Sand count:  294  Road Count:  4706
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 346 426 )
# Goal:( 700 583 )
# Goal:( 501 608 )
# Episode Done:All goals achieved
# Episode steps: 3592  Sand count:  172  Road Count:  3420
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 1415 626 )
# Episode Done:Max episode steps exhausted
# Episode steps: 5000  Sand count:  485  Road Count:  4515
# ---------------------------------------
# Average Reward over the Evaluation Step: -2212.833333
# ---------------------------------------
#
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 1415 626 )
# Episode Done:Max episode steps exhausted
# Episode steps: 5000  Sand count:  487  Road Count:  4513
# Total Timesteps: 68101 Episode Num: 26 Reward: -2752.100000000081
# Avg CriticLoss:  393.8119000396729  Avg ActorLoss  117.63258359375  ActorLR:  [7.290000000000001e-05]  CriticLR:  [5.314410000000002e-05]
#
# ----------- Evaluation -------------
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 1415 626 )
# Episode Done:Max episode steps exhausted
# Episode steps: 5000  Sand count:  130  Road Count:  4870
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Episode Done:Max episode steps exhausted
# Episode steps: 5000  Sand count:  72  Road Count:  4928
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Episode Done:Max episode steps exhausted
# Episode steps: 5000  Sand count:  72  Road Count:  4928
# ---------------------------------------
# Average Reward over the Evaluation Step: -1620.333333
# ---------------------------------------
#
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 472 335 )
# Episode Done:Max episode steps exhausted
# Episode steps: 5000  Sand count:  71  Road Count:  4929
# Total Timesteps: 73101 Episode Num: 27 Reward: -1867.5000000001005
# Avg CriticLoss:  405.1670137664795  Avg ActorLoss  119.63847993469238  ActorLR:  [7.290000000000001e-05]  CriticLR:  [4.782969000000002e-05]
#
# ----------- Evaluation -------------
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 1130 236 )
# Goal:( 611 29 )
# Goal:( 346 426 )
# Episode Done:All goals achieved
# Episode steps: 3820  Sand count:  358  Road Count:  3462
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 1130 236 )
# Goal:( 150 200 )
# Goal:( 346 426 )
# Episode Done:All goals achieved
# Episode steps: 2902  Sand count:  303  Road Count:  2599
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 346 426 )
# Goal:( 260 476 )
# Goal:( 885 568 )
# Episode Done:All goals achieved
# Episode steps: 1207  Sand count:  19  Road Count:  1188
# ---------------------------------------
# Average Reward over the Evaluation Step: -612.100000
# ---------------------------------------
#
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Episode Done:Max episode steps exhausted
# Episode steps: 5000  Sand count:  119  Road Count:  4881
# Total Timesteps: 78101 Episode Num: 28 Reward: -4585.700000000095
# Avg CriticLoss:  397.9440803771973  Avg ActorLoss  122.23137885131835  ActorLR:  [7.290000000000001e-05]  CriticLR:  [4.782969000000002e-05]
#
# ----------- Evaluation -------------
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 501 608 )
# Goal:( 611 29 )
# Episode Done:Max episode steps exhausted
# Episode steps: 5000  Sand count:  177  Road Count:  4823
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 150 200 )
# Goal:( 611 29 )
# Goal:( 1415 626 )
# Episode Done:All goals achieved
# Episode steps: 2364  Sand count:  564  Road Count:  1800
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 150 200 )
# Goal:( 346 426 )
# Goal:( 260 476 )
# Episode Done:All goals achieved
# Episode steps: 1483  Sand count:  218  Road Count:  1265
# ---------------------------------------
# Average Reward over the Evaluation Step: -1908.733333
# ---------------------------------------
#
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 1130 236 )
# Episode Done:Max episode steps exhausted
# Episode steps: 5000  Sand count:  219  Road Count:  4781
# Total Timesteps: 83101 Episode Num: 29 Reward: -1313.1000000000163
# Avg CriticLoss:  388.6409515640259  Avg ActorLoss  124.53087290039062  ActorLR:  [6.561000000000002e-05]  CriticLR:  [4.304672100000002e-05]
#
# ----------- Evaluation -------------
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 611 29 )
# Goal:( 1130 236 )
# Goal:( 1415 626 )
# Episode Done:All goals achieved
# Episode steps: 1532  Sand count:  7  Road Count:  1525
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 611 29 )
# Goal:( 1130 236 )
# Goal:( 260 476 )
# Episode Done:All goals achieved
# Episode steps: 1848  Sand count:  61  Road Count:  1787
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 260 476 )
# Goal:( 700 583 )
# Goal:( 611 29 )
# Episode Done:All goals achieved
# Episode steps: 2353  Sand count:  134  Road Count:  2219
# ---------------------------------------
# Average Reward over the Evaluation Step: 271.233333
# ---------------------------------------
#
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 150 200 )
# Goal:( 501 608 )
# Goal:( 1130 236 )
# Episode Done:All goals achieved
# Episode steps: 2668  Sand count:  394  Road Count:  2274
# Total Timesteps: 85769 Episode Num: 30 Reward: -1907.2000000000241
# Avg CriticLoss:  390.53845877697444  Avg ActorLoss  126.78083651998769  ActorLR:  [6.561000000000002e-05]  CriticLR:  [4.304672100000002e-05]
#
# ----------- Evaluation -------------
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 346 426 )
# Goal:( 1130 236 )
# Goal:( 150 200 )
# Episode Done:All goals achieved
# Episode steps: 2036  Sand count:  185  Road Count:  1851
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 700 583 )
# Goal:( 611 29 )
# Episode Done:Max episode steps exhausted
# Episode steps: 5000  Sand count:  505  Road Count:  4495
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 501 608 )
# Goal:( 611 29 )
# Goal:( 885 568 )
# Episode Done:All goals achieved
# Episode steps: 2425  Sand count:  168  Road Count:  2257
# ---------------------------------------
# Average Reward over the Evaluation Step: -1787.100000
# ---------------------------------------
#
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 346 426 )
# Goal:( 1130 236 )
# Goal:( 700 583 )
# Episode Done:All goals achieved
# Episode steps: 1923  Sand count:  111  Road Count:  1812
# Total Timesteps: 87692 Episode Num: 31 Reward: -583.9999999999962
# Avg CriticLoss:  404.8107351460807  Avg ActorLoss  126.98162581532559  ActorLR:  [6.561000000000002e-05]  CriticLR:  [4.304672100000002e-05]
#
# ----------- Evaluation -------------
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 885 568 )
# Goal:( 472 335 )
# Goal:( 700 583 )
# Episode Done:All goals achieved
# Episode steps: 2470  Sand count:  61  Road Count:  2409
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 700 583 )
# Goal:( 260 476 )
# Goal:( 501 608 )
# Episode Done:All goals achieved
# Episode steps: 2227  Sand count:  61  Road Count:  2166
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 611 29 )
# Goal:( 700 583 )
# Goal:( 260 476 )
# Episode Done:All goals achieved
# Episode steps: 2493  Sand count:  72  Road Count:  2421
# ---------------------------------------
# Average Reward over the Evaluation Step: -191.600000
# ---------------------------------------
#
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 1130 236 )
# Goal:( 700 583 )
# Goal:( 472 335 )
# Episode Done:All goals achieved
# Episode steps: 3937  Sand count:  334  Road Count:  3603
# Total Timesteps: 91629 Episode Num: 32 Reward: -1975.700000000032
# Avg CriticLoss:  393.6258470992131  Avg ActorLoss  127.84698294478986  ActorLR:  [6.561000000000002e-05]  CriticLR:  [3.874204890000002e-05]
#
# ----------- Evaluation -------------
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 150 200 )
# Goal:( 260 476 )
# Goal:( 1415 626 )
# Episode Done:All goals achieved
# Episode steps: 2113  Sand count:  212  Road Count:  1901
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 472 335 )
# Goal:( 346 426 )
# Goal:( 885 568 )
# Episode Done:All goals achieved
# Episode steps: 1653  Sand count:  39  Road Count:  1614
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 501 608 )
# Goal:( 1415 626 )
# Goal:( 346 426 )
# Episode Done:All goals achieved
# Episode steps: 2534  Sand count:  328  Road Count:  2206
# ---------------------------------------
# Average Reward over the Evaluation Step: -306.566667
# ---------------------------------------
#
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 346 426 )
# Goal:( 1415 626 )
# Goal:( 472 335 )
# Episode Done:All goals achieved
# Episode steps: 2247  Sand count:  119  Road Count:  2128
# Total Timesteps: 93876 Episode Num: 33 Reward: 533.6000000000005
# Avg CriticLoss:  388.3630938765522  Avg ActorLoss  128.60986044272138  ActorLR:  [6.561000000000002e-05]  CriticLR:  [3.874204890000002e-05]
#
# ----------- Evaluation -------------
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 346 426 )
# Goal:( 885 568 )
# Goal:( 472 335 )
# Episode Done:All goals achieved
# Episode steps: 1416  Sand count:  124  Road Count:  1292
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 611 29 )
# Goal:( 501 608 )
# Goal:( 700 583 )
# Episode Done:All goals achieved
# Episode steps: 1317  Sand count:  23  Road Count:  1294
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 1415 626 )
# Episode Done:Max episode steps exhausted
# Episode steps: 5000  Sand count:  201  Road Count:  4799
# ---------------------------------------
# Average Reward over the Evaluation Step: -269.233333
# ---------------------------------------
#
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 150 200 )
# Goal:( 700 583 )
# Episode Done:Max episode steps exhausted
# Episode steps: 5000  Sand count:  349  Road Count:  4651
# Total Timesteps: 98876 Episode Num: 34 Reward: -2376.7000000001353
# Avg CriticLoss:  369.211052432251  Avg ActorLoss  129.80827551879884  ActorLR:  [6.561000000000002e-05]  CriticLR:  [3.874204890000002e-05]
#
# ----------- Evaluation -------------
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 472 335 )
# Goal:( 1415 626 )
# Goal:( 501 608 )
# Episode Done:All goals achieved
# Episode steps: 2466  Sand count:  40  Road Count:  2426
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 700 583 )
# Goal:( 346 426 )
# Goal:( 260 476 )
# Episode Done:All goals achieved
# Episode steps: 2362  Sand count:  74  Road Count:  2288
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 472 335 )
# Goal:( 700 583 )
# Goal:( 611 29 )
# Episode Done:All goals achieved
# Episode steps: 1827  Sand count:  145  Road Count:  1682
# ---------------------------------------
# Average Reward over the Evaluation Step: 144.533333
# ---------------------------------------
#
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 472 335 )
# Goal:( 260 476 )
# Goal:( 611 29 )
# Episode Done:All goals achieved
# Episode steps: 1440  Sand count:  62  Road Count:  1378
# Total Timesteps: 100316 Episode Num: 35 Reward: 155.19999999999973
# Avg CriticLoss:  367.5012407037947  Avg ActorLoss  130.51277047263252  ActorLR:  [5.904900000000002e-05]  CriticLR:  [3.4867844010000016e-05]
#
# ----------- Evaluation -------------
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 150 200 )
# Goal:( 260 476 )
# Goal:( 700 583 )
# Episode Done:All goals achieved
# Episode steps: 2608  Sand count:  230  Road Count:  2378
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 885 568 )
# Goal:( 472 335 )
# Goal:( 346 426 )
# Episode Done:All goals achieved
# Episode steps: 1362  Sand count:  36  Road Count:  1326
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 150 200 )
# Goal:( 346 426 )
# Goal:( 885 568 )
# Episode Done:All goals achieved
# Episode steps: 1536  Sand count:  203  Road Count:  1333
# ---------------------------------------
# Average Reward over the Evaluation Step: -553.700000
# ---------------------------------------
#
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 1415 626 )
# Goal:( 150 200 )
# Goal:( 700 583 )
# Episode Done:All goals achieved
# Episode steps: 3492  Sand count:  90  Road Count:  3402
# Total Timesteps: 103808 Episode Num: 36 Reward: 736.0000000000108
# Avg CriticLoss:  374.94496778988486  Avg ActorLoss  130.72731615396435  ActorLR:  [5.904900000000002e-05]  CriticLR:  [3.4867844010000016e-05]
#
# ----------- Evaluation -------------
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 472 335 )
# Goal:( 611 29 )
# Goal:( 885 568 )
# Episode Done:All goals achieved
# Episode steps: 1643  Sand count:  36  Road Count:  1607
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 885 568 )
# Goal:( 1130 236 )
# Goal:( 1415 626 )
# Episode Done:All goals achieved
# Episode steps: 1464  Sand count:  51  Road Count:  1413
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 472 335 )
# Goal:( 700 583 )
# Goal:( 346 426 )
# Episode Done:All goals achieved
# Episode steps: 2103  Sand count:  81  Road Count:  2022
# ---------------------------------------
# Average Reward over the Evaluation Step: 337.000000
# ---------------------------------------
#
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 472 335 )
# Goal:( 700 583 )
# Goal:( 501 608 )
# Episode Done:All goals achieved
# Episode steps: 1446  Sand count:  70  Road Count:  1376
# Total Timesteps: 105254 Episode Num: 37 Reward: -85.99999999999937
# Avg CriticLoss:  340.25372585122517  Avg ActorLoss  130.91374333171925  ActorLR:  [5.904900000000002e-05]  CriticLR:  [3.4867844010000016e-05]
#
# ----------- Evaluation -------------
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 611 29 )
# Goal:( 472 335 )
# Goal:( 700 583 )
# Episode Done:All goals achieved
# Episode steps: 2467  Sand count:  82  Road Count:  2385
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 1130 236 )
# Goal:( 260 476 )
# Goal:( 472 335 )
# Episode Done:All goals achieved
# Episode steps: 2276  Sand count:  119  Road Count:  2157
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 472 335 )
# Goal:( 700 583 )
# Goal:( 346 426 )
# Episode Done:All goals achieved
# Episode steps: 2118  Sand count:  82  Road Count:  2036
# ---------------------------------------
# Average Reward over the Evaluation Step: -194.866667
# ---------------------------------------
#
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 501 608 )
# Goal:( 1415 626 )
# Goal:( 885 568 )
# Episode Done:All goals achieved
# Episode steps: 2070  Sand count:  51  Road Count:  2019
# Total Timesteps: 107324 Episode Num: 38 Reward: 621.7000000000024
# Avg CriticLoss:  351.44354203449933  Avg ActorLoss  130.47364965613914  ActorLR:  [5.904900000000002e-05]  CriticLR:  [3.4867844010000016e-05]
#
# ----------- Evaluation -------------
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 611 29 )
# Goal:( 260 476 )
# Goal:( 346 426 )
# Episode Done:All goals achieved
# Episode steps: 1676  Sand count:  16  Road Count:  1660
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 346 426 )
# Goal:( 472 335 )
# Goal:( 1415 626 )
# Episode Done:All goals achieved
# Episode steps: 1400  Sand count:  13  Road Count:  1387
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 472 335 )
# Goal:( 501 608 )
# Goal:( 611 29 )
# Episode Done:All goals achieved
# Episode steps: 1673  Sand count:  79  Road Count:  1594
# ---------------------------------------
# Average Reward over the Evaluation Step: 502.700000
# ---------------------------------------
#
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 611 29 )
# Goal:( 472 335 )
# Goal:( 700 583 )
# Episode Done:All goals achieved
# Episode steps: 2396  Sand count:  61  Road Count:  2335
# Total Timesteps: 109720 Episode Num: 39 Reward: 82.90000000000471
# Avg CriticLoss:  345.44490502792127  Avg ActorLoss  130.5071419984948  ActorLR:  [5.904900000000002e-05]  CriticLR:  [3.4867844010000016e-05]
#
# ----------- Evaluation -------------
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 260 476 )
# Goal:( 885 568 )
# Goal:( 150 200 )
# Episode Done:All goals achieved
# Episode steps: 1613  Sand count:  155  Road Count:  1458
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 1415 626 )
# Goal:( 885 568 )
# Goal:( 611 29 )
# Episode Done:All goals achieved
# Episode steps: 2561  Sand count:  122  Road Count:  2439
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 472 335 )
# Goal:( 260 476 )
# Goal:( 885 568 )
# Episode Done:All goals achieved
# Episode steps: 1799  Sand count:  93  Road Count:  1706
# ...
# Goal:( 1130 236 )
# Goal:( 611 29 )
# Episode Done:All goals achieved
# Episode steps: 1253  Sand count:  65  Road Count:  1188
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 260 476 )
# Goal:( 346 426 )
# Goal:( 885 568 )
# Episode Done:All goals achieved
# Episode steps: 862  Sand count:  89  Road Count:  773
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 1130 236 )
# Goal:( 501 608 )
# Goal:( 150 200 )
# Episode Done:All goals achieved
# Episode steps: 3211  Sand count:  389  Road Count:  2822
# ---------------------------------------
# Average Reward over the Evaluation Step: -236.766667
# ---------------------------------------
#
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 472 335 )
# Goal:( 346 426 )
# Goal:( 1415 626 )
# Episode Done:All goals achieved
# Episode steps: 2463  Sand count:  79  Road Count:  2384
# Total Timesteps: 165486 Episode Num: 63 Reward: 371.5999999999989
# Avg CriticLoss:  302.89595236180037  Avg ActorLoss  121.67104994742502  ActorLR:  [4.304672100000002e-05]  CriticLR:  [1.8530201888518422e-05]
#
# ----------- Evaluation -------------
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 611 29 )
# Goal:( 346 426 )
# Goal:( 260 476 )
# Episode Done:All goals achieved
# Episode steps: 1349  Sand count:  32  Road Count:  1317
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 611 29 )
# Goal:( 260 476 )
# Goal:( 472 335 )
# Episode Done:All goals achieved
# Episode steps: 1810  Sand count:  47  Road Count:  1763
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 1415 626 )
# Goal:( 611 29 )
# Goal:( 260 476 )
# Episode Done:All goals achieved
# Episode steps: 2627  Sand count:  71  Road Count:  2556
# ---------------------------------------
# Average Reward over the Evaluation Step: 591.533333
# ---------------------------------------
#
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 1130 236 )
# Goal:( 611 29 )
# Goal:( 260 476 )
# Episode Done:All goals achieved
# Episode steps: 2378  Sand count:  216  Road Count:  2162
# Total Timesteps: 167864 Episode Num: 64 Reward: -256.39999999999736
# Avg CriticLoss:  291.9805727702815  Avg ActorLoss  121.41635584209625  ActorLR:  [4.304672100000002e-05]  CriticLR:  [1.8530201888518422e-05]
#
# ----------- Evaluation -------------
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 611 29 )
# Goal:( 260 476 )
# Goal:( 700 583 )
# Episode Done:All goals achieved
# Episode steps: 2884  Sand count:  128  Road Count:  2756
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 501 608 )
# Goal:( 1415 626 )
# Goal:( 150 200 )
# Episode Done:All goals achieved
# Episode steps: 2142  Sand count:  157  Road Count:  1985
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 472 335 )
# Goal:( 1130 236 )
# Goal:( 611 29 )
# Episode Done:All goals achieved
# Episode steps: 1597  Sand count:  193  Road Count:  1404
# ---------------------------------------
# Average Reward over the Evaluation Step: -85.433333
# ---------------------------------------
#
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 611 29 )
# Goal:( 1415 626 )
# Goal:( 472 335 )
# Episode Done:All goals achieved
# Episode steps: 2613  Sand count:  459  Road Count:  2154
# Total Timesteps: 170477 Episode Num: 65 Reward: -1240.200000000002
# Avg CriticLoss:  297.42074827011  Avg ActorLoss  121.21133798919689  ActorLR:  [4.304672100000002e-05]  CriticLR:  [1.667718169966658e-05]
#
# ----------- Evaluation -------------
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 260 476 )
# Goal:( 501 608 )
# Goal:( 472 335 )
# Episode Done:All goals achieved
# Episode steps: 1191  Sand count:  18  Road Count:  1173
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 611 29 )
# Goal:( 700 583 )
# Goal:( 150 200 )
# Episode Done:All goals achieved
# Episode steps: 2402  Sand count:  80  Road Count:  2322
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 611 29 )
# Goal:( 700 583 )
# Goal:( 150 200 )
# Episode Done:All goals achieved
# Episode steps: 2402  Sand count:  80  Road Count:  2322
# ---------------------------------------
# Average Reward over the Evaluation Step: 102.100000
# ---------------------------------------
#
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 1415 626 )
# Goal:( 1130 236 )
# Goal:( 346 426 )
# Episode Done:All goals achieved
# Episode steps: 2339  Sand count:  183  Road Count:  2156
# Total Timesteps: 172816 Episode Num: 66 Reward: 237.39999999999978
# Avg CriticLoss:  283.6767485358869  Avg ActorLoss  120.34520520181317  ActorLR:  [4.304672100000002e-05]  CriticLR:  [1.667718169966658e-05]
#
# ----------- Evaluation -------------
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 885 568 )
# Goal:( 501 608 )
# Goal:( 700 583 )
# Episode Done:All goals achieved
# Episode steps: 2602  Sand count:  186  Road Count:  2416
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 611 29 )
# Goal:( 260 476 )
# Goal:( 1415 626 )
# Episode Done:All goals achieved
# Episode steps: 2927  Sand count:  71  Road Count:  2856
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 501 608 )
# Goal:( 700 583 )
# Goal:( 885 568 )
# Episode Done:All goals achieved
# Episode steps: 1350  Sand count:  122  Road Count:  1228
# ---------------------------------------
# Average Reward over the Evaluation Step: -124.933333
# ---------------------------------------
#
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 885 568 )
# Goal:( 260 476 )
# Goal:( 611 29 )
# Episode Done:All goals achieved
# Episode steps: 2313  Sand count:  78  Road Count:  2235
# Total Timesteps: 175129 Episode Num: 67 Reward: 233.5000000000022
# Avg CriticLoss:  287.6782316248292  Avg ActorLoss  120.47497992014607  ActorLR:  [4.304672100000002e-05]  CriticLR:  [1.667718169966658e-05]
#
# ----------- Evaluation -------------
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 885 568 )
# Goal:( 1130 236 )
# Goal:( 150 200 )
# Episode Done:All goals achieved
# Episode steps: 1867  Sand count:  171  Road Count:  1696
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 150 200 )
# Goal:( 1415 626 )
# Goal:( 501 608 )
# Episode Done:All goals achieved
# Episode steps: 3871  Sand count:  233  Road Count:  3638
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 346 426 )
# Goal:( 700 583 )
# Goal:( 1130 236 )
# Episode Done:All goals achieved
# Episode steps: 2175  Sand count:  146  Road Count:  2029
# ---------------------------------------
# Average Reward over the Evaluation Step: -299.300000
# ---------------------------------------
#
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 1415 626 )
# Goal:( 472 335 )
# Goal:( 700 583 )
# Episode Done:All goals achieved
# Episode steps: 2723  Sand count:  127  Road Count:  2596
# Total Timesteps: 177852 Episode Num: 68 Reward: 584.8000000000037
# Avg CriticLoss:  301.8847509237759  Avg ActorLoss  119.55370361910907  ActorLR:  [4.304672100000002e-05]  CriticLR:  [1.667718169966658e-05]
#
# ----------- Evaluation -------------
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 501 608 )
# Goal:( 260 476 )
# Goal:( 1130 236 )
# Episode Done:All goals achieved
# Episode steps: 1915  Sand count:  76  Road Count:  1839
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 700 583 )
# Goal:( 472 335 )
# Goal:( 150 200 )
# Episode Done:All goals achieved
# Episode steps: 1878  Sand count:  470  Road Count:  1408
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 501 608 )
# Goal:( 150 200 )
# Goal:( 1130 236 )
# Episode Done:All goals achieved
# Episode steps: 2298  Sand count:  254  Road Count:  2044
# ---------------------------------------
# Average Reward over the Evaluation Step: -1014.100000
# ---------------------------------------
#
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 472 335 )
# Goal:( 346 426 )
# Goal:( 1415 626 )
# Episode Done:All goals achieved
# Episode steps: 1966  Sand count:  135  Road Count:  1831
# Total Timesteps: 179818 Episode Num: 69 Reward: 62.89999999999884
# Avg CriticLoss:  292.8298632135711  Avg ActorLoss  119.52142996026444  ActorLR:  [4.304672100000002e-05]  CriticLR:  [1.667718169966658e-05]
#
# ----------- Evaluation -------------
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 346 426 )
# Goal:( 472 335 )
# Goal:( 885 568 )
# Episode Done:All goals achieved
# Episode steps: 857  Sand count:  91  Road Count:  766
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 501 608 )
# Goal:( 1415 626 )
# Goal:( 472 335 )
# Episode Done:All goals achieved
# Episode steps: 2164  Sand count:  159  Road Count:  2005
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 611 29 )
# Goal:( 150 200 )
# Goal:( 1415 626 )
# Episode Done:All goals achieved
# Episode steps: 2533  Sand count:  171  Road Count:  2362
# ---------------------------------------
# Average Reward over the Evaluation Step: 206.766667
# ---------------------------------------
#
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 885 568 )
# Goal:( 260 476 )
# Goal:( 346 426 )
# Episode Done:All goals achieved
# Episode steps: 2149  Sand count:  126  Road Count:  2023
# Total Timesteps: 181967 Episode Num: 70 Reward: -176.89999999999975
# Avg CriticLoss:  285.23156755677263  Avg ActorLoss  119.50968731453719  ActorLR:  [3.874204890000002e-05]  CriticLR:  [1.5009463529699922e-05]
#
# ----------- Evaluation -------------
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 501 608 )
# Goal:( 260 476 )
# Goal:( 700 583 )
# Episode Done:All goals achieved
# Episode steps: 1534  Sand count:  20  Road Count:  1514
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 260 476 )
# Goal:( 472 335 )
# Goal:( 501 608 )
# Episode Done:All goals achieved
# Episode steps: 987  Sand count:  126  Road Count:  861
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 700 583 )
# Goal:( 501 608 )
# Goal:( 611 29 )
# Episode Done:All goals achieved
# Episode steps: 2638  Sand count:  157  Road Count:  2481
# ---------------------------------------
# Average Reward over the Evaluation Step: -238.000000
# ---------------------------------------
#
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 260 476 )
# Goal:( 1415 626 )
# Goal:( 611 29 )
# Episode Done:All goals achieved
# Episode steps: 1836  Sand count:  42  Road Count:  1794
# Total Timesteps: 183803 Episode Num: 71 Reward: 751.6
# Avg CriticLoss:  276.71411627310295  Avg ActorLoss  119.00042260861865  ActorLR:  [3.874204890000002e-05]  CriticLR:  [1.5009463529699922e-05]
#
# ----------- Evaluation -------------
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 1415 626 )
# Goal:( 501 608 )
# Goal:( 472 335 )
# Episode Done:All goals achieved
# Episode steps: 3366  Sand count:  179  Road Count:  3187
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 700 583 )
# Goal:( 1130 236 )
# Goal:( 260 476 )
# Episode Done:All goals achieved
# Episode steps: 3091  Sand count:  257  Road Count:  2834
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 1415 626 )
# Goal:( 346 426 )
# Goal:( 472 335 )
# Episode Done:All goals achieved
# Episode steps: 2947  Sand count:  143  Road Count:  2804
# ---------------------------------------
# Average Reward over the Evaluation Step: 30.966667
# ---------------------------------------
#
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 700 583 )
# Goal:( 1130 236 )
# Goal:( 501 608 )
# Episode Done:All goals achieved
# Episode steps: 3594  Sand count:  257  Road Count:  3337
# Total Timesteps: 187397 Episode Num: 72 Reward: -505.299999999992
# Avg CriticLoss:  288.6016860711422  Avg ActorLoss  118.8925323019309  ActorLR:  [3.874204890000002e-05]  CriticLR:  [1.5009463529699922e-05]
#
# ----------- Evaluation -------------
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 700 583 )
# Goal:( 501 608 )
# Goal:( 1130 236 )
# Episode Done:All goals achieved
# Episode steps: 3176  Sand count:  417  Road Count:  2759
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 885 568 )
# Goal:( 346 426 )
# Goal:( 611 29 )
# Episode Done:All goals achieved
# Episode steps: 2321  Sand count:  108  Road Count:  2213
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 501 608 )
# Goal:( 1130 236 )
# Goal:( 472 335 )
# Episode Done:All goals achieved
# Episode steps: 2612  Sand count:  297  Road Count:  2315
# ---------------------------------------
# Average Reward over the Evaluation Step: -929.500000
# ---------------------------------------
#
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 885 568 )
# Goal:( 1415 626 )
# Goal:( 260 476 )
# Episode Done:All goals achieved
# Episode steps: 3778  Sand count:  192  Road Count:  3586
# Total Timesteps: 191175 Episode Num: 73 Reward: -17.999999999995822
# Avg CriticLoss:  293.42910264773997  Avg ActorLoss  118.77944529075481  ActorLR:  [3.874204890000002e-05]  CriticLR:  [1.350851717672993e-05]
#
# ----------- Evaluation -------------
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 260 476 )
# Goal:( 150 200 )
# Goal:( 1415 626 )
# Episode Done:All goals achieved
# Episode steps: 2054  Sand count:  231  Road Count:  1823
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 346 426 )
# Goal:( 885 568 )
# Goal:( 150 200 )
# Episode Done:All goals achieved
# Episode steps: 1973  Sand count:  168  Road Count:  1805
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 885 568 )
# Goal:( 346 426 )
# Goal:( 150 200 )
# Episode Done:All goals achieved
# Episode steps: 2305  Sand count:  264  Road Count:  2041
# ---------------------------------------
# Average Reward over the Evaluation Step: -673.500000
# ---------------------------------------
#
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
# Goal:( 885 568 )
# Goal:( 1415 626 )
# Goal:( 346 426 )
# Episode Done:All goals achieved
# Episode steps: 2187  Sand count:  50  Road Count:  2137
# Total Timesteps: 193362 Episode Num: 74 Reward: 923.7000000000007
# Avg CriticLoss:  281.857176293616  Avg ActorLoss  118.53147438164437  ActorLR:  [3.874204890000002e-05]  CriticLR:  [1.350851717672993e-05]
#
# ----------- Evaluation -------------
# imgPath:./car.png, width:20, height:10, velocityX:2.0, velocityY:0,angle:[10.], posX:188, posY:457
